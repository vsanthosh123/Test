# %% [markdown]
# <a href="https://colab.research.google.com/github/vss17/projects/blob/main/diabetes_predictive_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn import svm
from sklearn.preprocessing import StandardScaler

# %%
diabetes_data = pd.read_csv("diabetes.csv")

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data.shape
# Out:
# (768, 9)

# %%
diabetes_data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X=diabetes_data.drop(columns='Outcome', axis=1)
Y=diabetes_data['Outcome']

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
#standardization
scaler = StandardScaler()

# %%
scaler.fit(X)
standard = scaler.transform(X)

# %%
print(standard)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
x= standard
y= diabetes_data['Outcome']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, stratify=y,random_state=2)

# %%
x_train.shape
# Out:
# (614, 8)

# %%
x_test.shape
# Out:
# (154, 8)

# %%
#svm
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
#accuracy score
prediction = classifier.predict(x_train)
train_accuracy = accuracy_score(prediction,y_train)

# %%
print(train_accuracy)
# Out:
# 0.7866449511400652

# %%
test_prediction = classifier.predict(x_test)
test_accuracy = accuracy_score(test_prediction,y_test)
print(test_accuracy)
# Out:
# 0.7727272727272727

# %%
# making a predictive system
input_data =(4,110,92,0,0,37.6,0.191,30)
s=np.asarray(input_data)
model = s.reshape(1,-1)
std_data = scaler.transform(model)
prediction_n= classifier.predict(std_data)
print(prediction_n)
if prediction_n == 0:
  print("diabetes")
else:
  print("No diabetes" )
# Out:
# [0]
# diabetes
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
